# %%
#Q1
'''Matplotlib is a popular data visualization library in Python.'''
'''Wide Range of Plot Types: Matplotlib provides a variety of plot types to cater to different data visualization needs. These include line plots, scatter plots, bar plots, histogram plots, pie charts, box plots, and many more.

Integration with NumPy and Pandas: Matplotlib integrates well with other popular Python libraries such as NumPy and Pandas. It can directly work with arrays and data frames from these libraries, making it convenient for visualizing data stored in these formats.'''
'''Five plots are: bar plots, scatter plots, line plots, histogram, pie charts.'''
# Out:
# 'Five plots are: bar plots, scatter plots, line plots, histogram, pie charts.'

# %%
#Q2
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
print(x)
print(y)
plt.scatter(x,y)
plt.xlabel(x)
plt.ylabel(y)
plt.title('graph')
plt.show()
# Out:
# [ 6.57725695  3.8730197   3.19299494 -0.72698541  2.44522359  2.29048204
#   2.83451704  1.74599865  2.91236366  2.04556394  0.37227049  4.76924476
#   4.76263608  6.41914613  3.10006728  2.19064517  1.9092801  -0.09295463
#   4.96473487  0.79786474  0.62990695  2.5887002   5.97229671  3.47343253
#   0.95242972  1.5740136   4.25048993  2.67897327  1.4623273   2.53993856
#   4.49011253  6.95222157  0.51175334  1.74716618  1.39246781 -1.83816635
#   1.15241596  0.95224848  5.24795592  2.73617153 -0.24657089  4.2933509
#   2.28745848 -0.48628207  1.80670072  1.82281124  1.2522354   3.05942763
#  -1.49651554  2.46447627]
# [ 5.02636688  4.70559568  5.216375    5.23878131  5.97508626  0.76339863
#   4.69166681 -0.72177906  1.79422979 -0.82894409  5.09629502  5.66747564
#   2.60517064  6.54929006  1.65054498  3.30123373  3.30589141  0.87160945
#   3.87589322  6.87795692  0.95013825  4.79867689  2.6909863   6.53925461
# ...

# %%
#Q3
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title("Line 1")

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title("Line 2")

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title("Line 3")

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title("Line 4")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plots
plt.show()

# %%
#Q4
import numpy as np
import matplotlib.pyplot as plt
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.show()

# %%
#Q5
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2])
plt.show()
